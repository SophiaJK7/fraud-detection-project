# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

import pandas as pd
from src.feature_engineering import add_time_features, add_freq_velocity, get_preprocessor
from utils.helpers import validate_data
import numpy as np

# %% [markdown]
# # Audit Cleaned Data

# %%
# Define columns to parse as dates if present
DATE_COLS = ['signup_time', 'purchase_time']

def audit_all_cleaned_data(data_dir ='D:/Projects - AI & ML/fraud-detection-project/data/processed'):
    print(f"\n📁 Auditing all cleaned datasets in: {data_dir}")
    print("=" * 60)

    for filename in os.listdir(data_dir):
        if filename.endswith(".csv"):
            path = os.path.join(data_dir, filename)
            try:
                # Try parsing date columns if they exist
                df_sample = pd.read_csv(path, nrows=1)
                parse_cols = [col for col in DATE_COLS if col in df_sample.columns]
                df = pd.read_csv(path, parse_dates=parse_cols)

                # Run audit
                validate_data(df, name=filename)

            except Exception as e:
                print(f"❌ Failed to audit {filename}: {e}")

    print("\n✅ All audits complete.\n")

audit_all_cleaned_data()
# Out:
# 📁 Auditing all cleaned datasets in: D:/Projects - AI & ML/fraud-detection-project/data/processed
# ============================================================
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17000\4137065191.py:15: DtypeWarning: Columns (4,5,6,7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, parse_dates=parse_cols)
# 🔍 Auditing: combined.csv
# ==================================================
# Shape: (434838, 42)
# Columns: ['user_id', 'signup_time', 'purchase_time', 'purchase_value', 'device_id', 'source', 'browser', 'sex', 'age', 'class', 'ip_int', 'country', 'Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']
#
# Missing Values:
# user_id           283726
# signup_time       283726
# purchase_time     283726
# purchase_value    283726
# device_id         283726
# source            283726
# browser           283726
# sex               283726
# age               283726
# class                  0
# ip_int            283726
# country           284360
# Time              151112
# V1                151112
# V2                151112
# V3                151112
# V4                151112
# V5                151112
# V6                151112
# V7                151112
# V8                151112
# V9                151112
# V10               151112
# V11               151112
# V12               151112
# V13               151112
# V14               151112
# V15               151112
# V16               151112
# V17               151112
# V18               151112
# V19               151112
# V20               151112
# V21               151112
# V22               151112
# V23               151112
# V24               151112
# V25               151112
# V26               151112
# V27               151112
# V28               151112
# Amount            151112
# dtype: int64
#
# Data Types:
# user_id                  float64
# signup_time       datetime64[ns]
# purchase_time     datetime64[ns]
# purchase_value           float64
# device_id                 object
# source                    object
# browser                   object
# sex                       object
# age                      float64
# class                      int64
# ip_int                   float64
# country                   object
# Time                     float64
# V1                       float64
# V2                       float64
# V3                       float64
# V4                       float64
# V5                       float64
# V6                       float64
# V7                       float64
# V8                       float64
# V9                       float64
# V10                      float64
# V11                      float64
# V12                      float64
# V13                      float64
# V14                      float64
# V15                      float64
# V16                      float64
# V17                      float64
# V18                      float64
# V19                      float64
# V20                      float64
# V21                      float64
# V22                      float64
# V23                      float64
# V24                      float64
# V25                      float64
# V26                      float64
# V27                      float64
# V28                      float64
# Amount                   float64
# dtype: object
#
# Duplicate Rows: 0
#
# Numeric Summary:
#              user_id  purchase_value            age          class  \
# count  151112.000000   151112.000000  151112.000000  434838.000000
# mean   200171.040970       36.935372      33.140704       0.033631
# std    115369.285024       18.322762       8.617733       0.180277
# min         2.000000        9.000000      18.000000       0.000000
# 25%    100642.500000       22.000000      27.000000       0.000000
# 50%    199958.000000       35.000000      33.000000       0.000000
# 75%    300054.000000       49.000000      39.000000       0.000000
# max    400000.000000      154.000000      76.000000       1.000000
#
#              ip_int           Time             V1             V2  \
# count  1.511120e+05  283726.000000  283726.000000  283726.000000
# mean   2.152145e+09   94811.077600       0.005917      -0.004135
# std    1.248497e+09   47481.047891       1.948026       1.646703
# min    5.209300e+04       0.000000     -56.407510     -72.715728
# 25%    1.085934e+09   54204.750000      -0.915951      -0.600321
# 50%    2.154770e+09   84692.500000       0.020384       0.063949
# 75%    3.243258e+09  139298.000000       1.316068       0.800283
# max    4.294850e+09  172792.000000       2.454930      22.057729
#
#                   V3             V4  ...            V20            V21  \
# count  283726.000000  283726.000000  ...  283726.000000  283726.000000
# mean        0.001613      -0.002966  ...       0.000187      -0.000371
# std         1.508682       1.414184  ...       0.769984       0.723909
# min       -48.325589      -5.683171  ...     -54.497720     -34.830382
# 25%        -0.889682      -0.850134  ...      -0.211469      -0.228305
# 50%         0.179963      -0.022248  ...      -0.062353      -0.029441
# 75%         1.026960       0.739647  ...       0.133207       0.186194
# max         9.382558      16.875344  ...      39.420904      27.202839
#
#                  V22            V23            V24            V25  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.000015       0.000198       0.000214      -0.000232
# std         0.724550       0.623702       0.605627       0.521220
# min       -10.933144     -44.807735      -2.836627     -10.295397
# 25%        -0.542700      -0.161703      -0.354453      -0.317485
# 50%         0.006675      -0.011159       0.041016       0.016278
# 75%         0.528245       0.147748       0.439738       0.350667
# max        10.503090      22.528412       4.584549       7.519589
#
#                  V26            V27            V28         Amount
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean        0.000149       0.001763       0.000547      88.472687
# std         0.482053       0.395744       0.328027     250.399437
# min        -2.604551     -22.565679     -15.430084       0.000000
# 25%        -0.326763      -0.070641      -0.052818       5.600000
# 50%        -0.052172       0.001479       0.011288      22.000000
# 75%         0.240261       0.091208       0.078276      77.510000
# max         3.517346      31.612198      33.847808   25691.160000
#
# [8 rows x 35 columns]
#
# Categorical Summary:
# device_id: 137956 unique values
# device_id
# NaN              283726
# CQTUVBYIWWWBC        20
# KIPFSCNUGOLDP        20
# ITUMJCKWEYNDD        20
# ZUSVMDEZRBDTX        20
# Name: count, dtype: int64
# --------------------
# source: 3 unique values
# source
# NaN       283726
# SEO        60615
# Ads        59881
# Direct     30616
# Name: count, dtype: int64
# --------------------
# browser: 5 unique values
# browser
# NaN        283726
# Chrome      61432
# IE          36727
# Safari      24667
# FireFox     24610
# Name: count, dtype: int64
# --------------------
# sex: 2 unique values
# sex
# NaN    283726
# M       88293
# F       62819
# Name: count, dtype: int64
# --------------------
# country: 181 unique values
# country
# NaN              284360
# United States     59222
# Australia         21228
# China             12038
# Japan              7918
# Name: count, dtype: int64
# --------------------
# ==================================================
# ✅ Audit complete.
#
#
# 🔍 Auditing: credit_clean.csv
# ==================================================
# Shape: (283726, 31)
# Columns: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'class']
#
# Missing Values:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# class     0
# dtype: int64
#
# Data Types:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# class       int64
# dtype: object
#
# Duplicate Rows: 0
#
# Numeric Summary:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# 25%        -0.850134      -0.689830      -0.769031      -0.552509
# 50%        -0.022248      -0.053468      -0.275168       0.040859
# 75%         0.739647       0.612218       0.396792       0.570474
# max        16.875344      34.801666      73.301626     120.589494
#
#                   V8             V9  ...            V21            V22  \
# count  283726.000000  283726.000000  ...  283726.000000  283726.000000
# mean       -0.000854      -0.001596  ...      -0.000371      -0.000015
# std         1.179054       1.095492  ...       0.723909       0.724550
# min       -73.216718     -13.434066  ...     -34.830382     -10.933144
# 25%        -0.208828      -0.644221  ...      -0.228305      -0.542700
# 50%         0.021898      -0.052596  ...      -0.029441       0.006675
# 75%         0.325704       0.595977  ...       0.186194       0.528245
# max        20.007208      15.594995  ...      27.202839      10.503090
#
#                  V23            V24            V25            V26  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean        0.000198       0.000214      -0.000232       0.000149
# std         0.623702       0.605627       0.521220       0.482053
# min       -44.807735      -2.836627     -10.295397      -2.604551
# 25%        -0.161703      -0.354453      -0.317485      -0.326763
# 50%        -0.011159       0.041016       0.016278      -0.052172
# 75%         0.147748       0.439738       0.350667       0.240261
# max        22.528412       4.584549       7.519589       3.517346
#
#                  V27            V28         Amount          class
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean        0.001763       0.000547      88.472687       0.001667
# std         0.395744       0.328027     250.399437       0.040796
# min       -22.565679     -15.430084       0.000000       0.000000
# 25%        -0.070641      -0.052818       5.600000       0.000000
# 50%         0.001479       0.011288      22.000000       0.000000
# 75%         0.091208       0.078276      77.510000       0.000000
# max        31.612198      33.847808   25691.160000       1.000000
#
# [8 rows x 31 columns]
# ==================================================
# ✅ Audit complete.
#
#
# 🔍 Auditing: fraud_clean.csv
# ==================================================
# Shape: (151112, 12)
# Columns: ['user_id', 'signup_time', 'purchase_time', 'purchase_value', 'device_id', 'source', 'browser', 'sex', 'age', 'class', 'ip_int', 'country']
#
# Missing Values:
# user_id             0
# signup_time         0
# purchase_time       0
# purchase_value      0
# device_id           0
# source              0
# browser             0
# sex                 0
# age                 0
# class               0
# ip_int              0
# country           634
# dtype: int64
#
# Data Types:
# user_id                    int64
# signup_time       datetime64[ns]
# purchase_time     datetime64[ns]
# purchase_value             int64
# device_id                 object
# source                    object
# browser                   object
# sex                       object
# age                        int64
# class                      int64
# ip_int                     int64
# country                   object
# dtype: object
#
# Duplicate Rows: 0
#
# Numeric Summary:
#              user_id  purchase_value            age          class  \
# count  151112.000000   151112.000000  151112.000000  151112.000000
# mean   200171.040970       36.935372      33.140704       0.093646
# std    115369.285024       18.322762       8.617733       0.291336
# min         2.000000        9.000000      18.000000       0.000000
# 25%    100642.500000       22.000000      27.000000       0.000000
# 50%    199958.000000       35.000000      33.000000       0.000000
# 75%    300054.000000       49.000000      39.000000       0.000000
# max    400000.000000      154.000000      76.000000       1.000000
#
#              ip_int
# count  1.511120e+05
# mean   2.152145e+09
# std    1.248497e+09
# min    5.209300e+04
# 25%    1.085934e+09
# 50%    2.154770e+09
# 75%    3.243258e+09
# max    4.294850e+09
#
# Categorical Summary:
# device_id: 137956 unique values
# device_id
# EQYVNEGOFLAWK    20
# CQTUVBYIWWWBC    20
# ZUSVMDEZRBDTX    20
# NGQCKIADMZORL    20
# ITUMJCKWEYNDD    20
# Name: count, dtype: int64
# --------------------
# source: 3 unique values
# source
# SEO       60615
# Ads       59881
# Direct    30616
# Name: count, dtype: int64
# --------------------
# browser: 5 unique values
# browser
# Chrome     61432
# IE         36727
# Safari     24667
# FireFox    24610
# Opera       3676
# Name: count, dtype: int64
# --------------------
# sex: 2 unique values
# sex
# M    88293
# F    62819
# Name: count, dtype: int64
# --------------------
# country: 181 unique values
# country
# United States     59222
# Australia         21228
# China             12038
# Japan              7918
# United Kingdom     4492
# Name: count, dtype: int64
# --------------------
# ==================================================
# ✅ Audit complete.
#
#
# 🔍 Auditing: fraud_geo.csv
# ==================================================
# Shape: (151112, 19)
# Columns: ['user_id', 'signup_time', 'purchase_time', 'purchase_value', 'device_id', 'source', 'browser', 'sex', 'age', 'ip_address', 'class', 'ip_int', 'country', 'hour_of_day', 'day_of_week', 'time_since_signup', 'purchase_count', 'prev_purchase_time', 'time_since_prev_sec']
#
# Missing Values:
# user_id                     0
# signup_time                 0
# purchase_time               0
# purchase_value              0
# device_id                   0
# source                      0
# browser                     0
# sex                         0
# age                         0
# ip_address                  0
# class                       0
# ip_int                      0
# country                   634
# hour_of_day                 0
# day_of_week                 0
# time_since_signup           0
# purchase_count              0
# prev_purchase_time     151112
# time_since_prev_sec    151112
# dtype: int64
#
# Data Types:
# user_id                         int64
# signup_time            datetime64[ns]
# purchase_time          datetime64[ns]
# purchase_value                  int64
# device_id                      object
# source                         object
# browser                        object
# sex                            object
# age                             int64
# ip_address                    float64
# class                           int64
# ip_int                          int64
# country                        object
# hour_of_day                     int64
# day_of_week                    object
# time_since_signup             float64
# purchase_count                  int64
# prev_purchase_time            float64
# time_since_prev_sec           float64
# dtype: object
#
# Duplicate Rows: 0
#
# Numeric Summary:
#              user_id  purchase_value            age    ip_address  \
# count  151112.000000   151112.000000  151112.000000  1.511120e+05
# mean   200171.040970       36.935372      33.140704  2.152145e+09
# std    115369.285024       18.322762       8.617733  1.248497e+09
# min         2.000000        9.000000      18.000000  5.209350e+04
# 25%    100642.500000       22.000000      27.000000  1.085934e+09
# 50%    199958.000000       35.000000      33.000000  2.154770e+09
# 75%    300054.000000       49.000000      39.000000  3.243258e+09
# max    400000.000000      154.000000      76.000000  4.294850e+09
#
#                class        ip_int    hour_of_day  time_since_signup  \
# count  151112.000000  1.511120e+05  151112.000000       1.511120e+05
# mean        0.093646  2.152145e+09      11.521593       4.932029e+06
# std         0.291336  1.248497e+09       6.912474       3.126263e+06
# min         0.000000  5.209300e+04       0.000000       1.000000e+00
# 25%         0.000000  1.085934e+09       6.000000       2.186754e+06
# 50%         0.000000  2.154770e+09      12.000000       4.926346e+06
# 75%         0.000000  3.243258e+09      17.000000       7.644524e+06
# max         1.000000  4.294850e+09      23.000000       1.036797e+07
#
#        purchase_count  prev_purchase_time  time_since_prev_sec
# count        151112.0                 0.0                  0.0
# mean              1.0                 NaN                  NaN
# std               0.0                 NaN                  NaN
# min               1.0                 NaN                  NaN
# 25%               1.0                 NaN                  NaN
# 50%               1.0                 NaN                  NaN
# 75%               1.0                 NaN                  NaN
# max               1.0                 NaN                  NaN
#
# Categorical Summary:
# device_id: 137956 unique values
# device_id
# ITUMJCKWEYNDD    20
# KIPFSCNUGOLDP    20
# NGQCKIADMZORL    20
# ZUSVMDEZRBDTX    20
# CQTUVBYIWWWBC    20
# Name: count, dtype: int64
# --------------------
# source: 3 unique values
# source
# SEO       60615
# Ads       59881
# Direct    30616
# Name: count, dtype: int64
# --------------------
# browser: 5 unique values
# browser
# Chrome     61432
# IE         36727
# Safari     24667
# FireFox    24610
# Opera       3676
# Name: count, dtype: int64
# --------------------
# sex: 2 unique values
# sex
# M    88293
# F    62819
# Name: count, dtype: int64
# --------------------
# country: 181 unique values
# country
# United States     59222
# Australia         21228
# China             12038
# Japan              7918
# United Kingdom     4492
# Name: count, dtype: int64
# --------------------
# day_of_week: 7 unique values
# day_of_week
# Sunday      22015
# Monday      21711
# Saturday    21648
# Thursday    21586
# Friday      21522
# Name: count, dtype: int64
# --------------------
# ==================================================
# ✅ Audit complete.
#
#
# ✅ All audits complete.

# %% [markdown]
# # Feature engineering (example on fraud)

# %%
fraud = add_time_features(fraud)
fraud = add_freq_velocity(fraud)

# Select features & target
X = fraud[[
    'purchase_value','age','time_since_signup','time_since_prev',
    'source','browser','sex','country','hour_of_day','day_of_week'
]]
y = fraud['class']

preproc = get_preprocessor(
    num_feats=['purchase_value','age','time_since_signup','time_since_prev'],
    cat_feats=['source','browser','sex','country','hour_of_day','day_of_week']
)

X_proc = preproc.fit_transform(X)
